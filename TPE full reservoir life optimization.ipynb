# %% [markdown]
# # Import Models

# %%
import os
import subprocess
import pandas as pd
import numpy as np
import optuna
from optuna.samplers import NSGAIIISampler
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %% [markdown]
# # Build the python script for simulation running

# %%
ECLRUN_EXE = r"C:\ecl\macros\eclrun.exe"

BASE_DIR = r"C:\Users\hp\Desktop\EclipseFullEgg"  # we did the simulation for TPE & NSGA on the same DATA file 

DATA_FILE_NAME = "Egg_Model_ECL.DATA"
SCHEDULE_FILE_NAME = "SCHEDULE_NEW.INC"
RSM_PATH = r"C:\Users\hp\Desktop\EclipseFullEgg\EGG_MODEL_ECL.RSM"

# %%
def modify_files(params):
#____________________________________________________________
    sched_path = os.path.join(BASE_DIR, SCHEDULE_FILE_NAME)

    inj_map = {
        "INJECT1": params["inj_rate1"],
        "INJECT2": params["inj_rate2"],
        "INJECT3": params["inj_rate3"],
        "INJECT4": params["inj_rate4"],
        "INJECT5": params["inj_rate5"],
        "INJECT6": params["inj_rate6"],
        "INJECT7": params["inj_rate7"],
        "INJECT8": params["inj_rate8"],
    }

    with open(sched_path, "r") as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        stripped = line.strip()

        for well, rate in inj_map.items():
            if stripped.startswith(f"'{well}'") and "'RATE'" in stripped:
                parts = stripped.split()

                # Find RATE keyword index safely
                rate_idx = parts.index("'RATE'") + 1
                parts[rate_idx] = str(int(rate))

                line = " ".join(parts) + "\n"

        new_lines.append(line)

    with open(sched_path, "w") as f:
        f.writelines(new_lines)

#_____________________________________________________________
    data_path = os.path.join(BASE_DIR, DATA_FILE_NAME)

    prod_map = {
        "PROD1": params["BHP1"],
        "PROD2": params["BHP2"],
        "PROD3": params["BHP3"],
        "PROD4": params["BHP4"],
    }
    with open(data_path, "r") as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        stripped = line.strip()

        for well, bhp in prod_map.items():
            if stripped.startswith(f"'{well}'") and "'BHP'" in stripped:
                parts = stripped.split()
                parts[-1] = f"{int(bhp)}/"
                line = " ".join(parts) + "\n"

        new_lines.append(line)

    with open(data_path, "w") as f:
        f.writelines(new_lines)

# %%
def run_eclipse():
    cmd = [
        ECLRUN_EXE,
        "eclipse",
        DATA_FILE_NAME
    ]
    subprocess.run(cmd, cwd=BASE_DIR, check=True)
    
def extract_FOPT_FWPT_from_RSM(rsm_path):

    with open(rsm_path, "r") as f:
        lines = f.readlines()

    inside_summary = False
    fopt_idx = fwpt_idx = None

    for line in lines:

        if "SUMMARY OF RUN" in line:
            inside_summary = True
            fopt_idx = fwpt_idx = None
            continue

        if not inside_summary:
            continue

        tokens = line.split()
        if not tokens:
            continue

        # Detect column headers
        if fopt_idx is None and "FOPT" in tokens and "FWPT" in tokens:
            fopt_idx = tokens.index("FOPT")
            fwpt_idx = tokens.index("FWPT")
            continue

        if fopt_idx is None:
            continue

        # ✅ Only data rows have numeric TIME
        if not tokens[0][0].isdigit():
            continue
        if float(tokens[0]) == 3600.0:
            return float(tokens[fopt_idx]), float(tokens[fwpt_idx])

# %% [markdown]
# # Define the TPE objective function

# %%
def objective(trial):

    # ---------------------------------------------
    # 1. TPE parameter suggestions
    # ---------------------------------------------
    params = {
        "BHP1": trial.suggest_int("BHP1", 150, 390),
        "BHP2": trial.suggest_int("BHP2", 150, 390),
        "BHP3": trial.suggest_int("BHP3", 150, 390),
        "BHP4": trial.suggest_int("BHP4", 150, 390),
        "inj_rate1": trial.suggest_int("inj_rate1", 50, 400),
        "inj_rate2": trial.suggest_int("inj_rate2", 50, 400),
        "inj_rate3": trial.suggest_int("inj_rate3", 50, 400),
        "inj_rate4": trial.suggest_int("inj_rate4", 50, 400),
        "inj_rate5": trial.suggest_int("inj_rate5", 50, 400),
        "inj_rate6": trial.suggest_int("inj_rate6", 50, 400),
        "inj_rate7": trial.suggest_int("inj_rate7", 50, 400),
        "inj_rate8": trial.suggest_int("inj_rate8", 50, 400),
    }

    # ---------------------------------------------
    # 2. Modify Eclipse input files
    # ---------------------------------------------
    modify_files(params)

    # ---------------------------------------------
    # 3. Run Eclipse
    # ---------------------------------------------
    try:
        run_eclipse()
    except subprocess.CalledProcessError:
        # Penalize failed runs
        return -1e12, 1e12

    # ---------------------------------------------
    # 4. Read results
    # ---------------------------------------------
    fopt, fwpt = extract_FOPT_FWPT_from_RSM(
        RSM_PATH
    )

    # ---------------------------------------------
    # 5. Multi-objective return
    # ---------------------------------------------
    return fopt , fwpt

# %% [markdown]
# # TPE optimization running

# %%
sampler1 = optuna.samplers.TPESampler(
    n_startup_trials=42,
    multivariate=False,
    seed=42)

study1 = optuna.create_study(
    directions=["maximize", "minimize"],
    sampler=sampler1,
    study_name="ECLIPSE_SUM_DELTA_FOPT_FWPT"
)

study1.optimize(objective, n_trials=300, show_progress_bar=False)
# Out:
# [I 2026-03-21 17:05:03,814] A new study created in memory with name: ECLIPSE_SUM_DELTA_FOPT_FWPT
# [I 2026-03-21 17:06:09,188] Trial 0 finished with values: [542456.4, 5351730.0] and parameters: {'BHP1': 240, 'BHP2': 379, 'BHP3': 326, 'BHP4': 294, 'inj_rate1': 104, 'inj_rate2': 104, 'inj_rate3': 70, 'inj_rate4': 354, 'inj_rate5': 260, 'inj_rate6': 298, 'inj_rate7': 57, 'inj_rate8': 390}.
# [I 2026-03-21 17:07:50,507] Trial 1 finished with values: [538358.4, 4629445.0] and parameters: {'BHP1': 350, 'BHP2': 201, 'BHP3': 193, 'BHP4': 194, 'inj_rate1': 156, 'inj_rate2': 234, 'inj_rate3': 201, 'inj_rate4': 152, 'inj_rate5': 264, 'inj_rate6': 98, 'inj_rate7': 152, 'inj_rate8': 178}.
# [I 2026-03-21 17:09:53,166] Trial 2 finished with values: [541525.1, 6195296.0] and parameters: {'BHP1': 259, 'BHP2': 339, 'BHP3': 198, 'BHP4': 273, 'inj_rate1': 257, 'inj_rate2': 66, 'inj_rate3': 263, 'inj_rate4': 109, 'inj_rate5': 72, 'inj_rate6': 383, 'inj_rate7': 388, 'inj_rate8': 333}.
# [I 2026-03-21 17:11:29,107] Trial 3 finished with values: [534377.2, 5079976.0] and parameters: {'BHP1': 223, 'BHP2': 173, 'BHP3': 314, 'BHP4': 256, 'inj_rate1': 92, 'inj_rate2': 223, 'inj_rate3': 62, 'inj_rate4': 369, 'inj_rate5': 140, 'inj_rate6': 282, 'inj_rate7': 159, 'inj_rate8': 232}.
# [I 2026-03-21 17:13:46,408] Trial 4 finished with values: [539645.1, 5952888.0] and parameters: {'BHP1': 281, 'BHP2': 194, 'BHP3': 383, 'BHP4': 336, 'inj_rate1': 379, 'inj_rate2': 364, 'inj_rate3': 259, 'inj_rate4': 373, 'inj_rate5': 81, 'inj_rate6': 118, 'inj_rate7': 65, 'inj_rate8': 164}.
# [I 2026-03-21 17:14:39,251] Trial 5 finished with values: [542464.2, 5687075.0] and parameters: {'BHP1': 243, 'BHP2': 215, 'BHP3': 349, 'BHP4': 235, 'inj_rate1': 148, 'inj_rate2': 240, 'inj_rate3': 99, 'inj_rate4': 331, 'inj_rate5': 76, 'inj_rate6': 396, 'inj_rate7': 321, 'inj_rate8': 119}.
# [I 2026-03-21 17:16:09,338] Trial 6 finished with values: [532391.6, 4934206.0] and parameters: {'BHP1': 151, 'BHP2': 346, 'BHP3': 320, 'BHP4': 325, 'inj_rate1': 320, 'inj_rate2': 75, 'inj_rate3': 175, 'inj_rate4': 90, 'inj_rate5': 352, 'inj_rate6': 268, 'inj_rate7': 166, 'inj_rate8': 72}.
# [I 2026-03-21 17:18:41,670] Trial 7 finished with values: [545021.6, 6922844.0] and parameters: {'BHP1': 224, 'BHP2': 228, 'BHP3': 325, 'BHP4': 303, 'inj_rate1': 361, 'inj_rate2': 215, 'inj_rate3': 91, 'inj_rate4': 300, 'inj_rate5': 317, 'inj_rate6': 247, 'inj_rate7': 320, 'inj_rate8': 223}.
# [I 2026-03-21 17:19:39,746] Trial 8 finished with values: [539423.2, 5712021.0] and parameters: {'BHP1': 275, 'BHP2': 253, 'BHP3': 156, 'BHP4': 176, 'inj_rate1': 61, 'inj_rate2': 273, 'inj_rate3': 160, 'inj_rate4': 228, 'inj_rate5': 368, 'inj_rate6': 137, 'inj_rate7': 194, 'inj_rate8': 315}.
# [I 2026-03-21 17:21:05,750] Trial 9 finished with values: [551196.8, 8036750.0] and parameters: {'BHP1': 205, 'BHP2': 168, 'BHP3': 219, 'BHP4': 188, 'inj_rate1': 376, 'inj_rate2': 333, 'inj_rate3': 272, 'inj_rate4': 355, 'inj_rate5': 332, 'inj_rate6': 115, 'inj_rate7': 363, 'inj_rate8': 239}.
# [I 2026-03-21 17:22:09,045] Trial 10 finished with values: [542946.9, 5297810.0] and parameters: {'BHP1': 344, 'BHP2': 365, 'BHP3': 226, 'BHP4': 176, 'inj_rate1': 130, 'inj_rate2': 199, 'inj_rate3': 337, 'inj_rate4': 352, 'inj_rate5': 52, 'inj_rate6': 229, 'inj_rate7': 196, 'inj_rate8': 127}.
# [I 2026-03-21 17:22:57,043] Trial 11 finished with values: [548992.5, 6652604.0] and parameters: {'BHP1': 178, 'BHP2': 231, 'BHP3': 377, 'BHP4': 227, 'inj_rate1': 232, 'inj_rate2': 296, 'inj_rate3': 177, 'inj_rate4': 391, 'inj_rate5': 387, 'inj_rate6': 138, 'inj_rate7': 224, 'inj_rate8': 155}.
# [I 2026-03-22 08:17:41,790] Trial 295 finished with values: [524961.8, 3188374.0] and parameters: {'BHP1': 360, 'BHP2': 204, 'BHP3': 245, 'BHP4': 207, 'inj_rate1': 109, 'inj_rate2': 127, 'inj_rate3': 64, 'inj_rate4': 98, 'inj_rate5': 63, 'inj_rate6': 264, 'inj_rate7': 238, 'inj_rate8': 68}.
# [I 2026-03-22 08:18:58,038] Trial 296 finished with values: [535762.1, 4203964.0] and parameters: {'BHP1': 380, 'BHP2': 318, 'BHP3': 390, 'BHP4': 233, 'inj_rate1': 101, 'inj_rate2': 191, 'inj_rate3': 166, 'inj_rate4': 86, 'inj_rate5': 102, 'inj_rate6': 254, 'inj_rate7': 138, 'inj_rate8': 279}.
# [I 2026-03-22 08:20:11,409] Trial 297 finished with values: [523705.4, 2880091.0] and parameters: {'BHP1': 375, 'BHP2': 195, 'BHP3': 372, 'BHP4': 364, 'inj_rate1': 93, 'inj_rate2': 60, 'inj_rate3': 50, 'inj_rate4': 75, 'inj_rate5': 72, 'inj_rate6': 379, 'inj_rate7': 159, 'inj_rate8': 57}.
# [I 2026-03-22 08:25:59,338] Trial 298 finished with values: [522562.7, 4288906.0] and parameters: {'BHP1': 366, 'BHP2': 197, 'BHP3': 160, 'BHP4': 359, 'inj_rate1': 117, 'inj_rate2': 71, 'inj_rate3': 129, 'inj_rate4': 230, 'inj_rate5': 221, 'inj_rate6': 355, 'inj_rate7': 156, 'inj_rate8': 57}.
# [I 2026-03-22 08:28:23,367] Trial 299 finished with values: [543081.1, 6151255.0] and parameters: {'BHP1': 173, 'BHP2': 198, 'BHP3': 265, 'BHP4': 154, 'inj_rate1': 194, 'inj_rate2': 158, 'inj_rate3': 270, 'inj_rate4': 391, 'inj_rate5': 70, 'inj_rate6': 80, 'inj_rate7': 382, 'inj_rate8': 314}.

# %% [markdown]
# # Optimization results

# %%
pareto_trials = study1.best_trials
fopts = [t.values[0] for t in study1.trials if t.values is not None]
fwpts = [t.values[1] for t in study1.trials if t.values is not None]

plt.figure(figsize=(7,5),dpi=100)
plt.scatter(fwpts, fopts, c='blue')
plt.xlabel("FWPT (SM3)")
plt.ylabel("FOPT (SM3)")
plt.grid(True, which="major", linestyle="--", linewidth=0.9, alpha=0.7)
plt.grid(True, which="minor", linestyle="--", linewidth=0.5, alpha=0.4)
plt.show()

# %%
fopts = [t.values[0] for t in study1.trials if t.values is not None]
fwpts = [t.values[1] for t in study1.trials if t.values is not None]

# --- Pareto optimal trials ---
pareto_trials = study1.best_trials
pareto_fopts = [t.values[0] for t in pareto_trials]
pareto_fwpts = [t.values[1] for t in pareto_trials]

# --- Sort Pareto points by FWPT (minimization axis) ---
pareto_points = sorted(zip(pareto_fwpts, pareto_fopts))
pareto_fwpts_sorted, pareto_fopts_sorted = zip(*pareto_points)

plt.figure()

# All solutions
plt.scatter(fwpts, fopts, color='blue', alpha=0.6, label='All Trials')

# Pareto points
plt.scatter(pareto_fwpts_sorted, pareto_fopts_sorted,
            color='red', marker='^', s=70, label='Pareto Point')

plt.xlabel("FWPT (SM3)")
plt.ylabel("FOPT (SM3)")
plt.legend()
plt.grid(True)

plt.show()

# %%
FOPT = np.array([t.values[0] for t in pareto_trials])
FWPT = np.array([t.values[1] for t in pareto_trials])

# normalize
FOPT_n = (FOPT - FOPT.min())/(FOPT.max()-FOPT.min())
FWPT_n = (FWPT - FWPT.min())/(FWPT.max()-FWPT.min())

dist = np.sqrt((1 - FOPT_n)**2 + FWPT_n**2)

best_idx = np.argmin(dist)
best_trial = pareto_trials[best_idx]

print("\nSelected Best Solution:\n")
print("Trial:", best_trial.number)
print("FOPT:", best_trial.values[0])
print("FWPT:", best_trial.values[1])
print("Parameters:", best_trial.params)
# Out:
# Selected Best Solution:
#
# Trial: 121
# FOPT: 543399.8
# FWPT: 4105474.0
# Parameters: {'BHP1': 337, 'BHP2': 299, 'BHP3': 300, 'BHP4': 208, 'inj_rate1': 335, 'inj_rate2': 52, 'inj_rate3': 130, 'inj_rate4': 59, 'inj_rate5': 110, 'inj_rate6': 339, 'inj_rate7': 69, 'inj_rate8': 197}

# %%
print("\nPareto Front Table\n")
print("Trial\tFOPT\tFWPT")

for trial in pareto_trials:
    print(f"{trial.number}\t{trial.values[0]:.2f}\t{trial.values[1]:.2f}")
# Out:
# Pareto Front Table
#
# Trial	FOPT	FWPT
# 99	551243.70	5318491.00
# 108	541661.80	4006628.00
# 119	545717.10	4589998.00
# 121	543399.80	4105474.00
# 125	543941.10	4317610.00
# 128	560304.80	7145056.00
# 131	545695.80	4406054.00
# 134	550974.30	5292198.00
# 140	552284.10	5432694.00
# 143	548916.20	4896096.00
# 167	537733.50	3701111.00
# 171	538788.40	3743232.00
# 178	551276.90	5322482.00
# 190	517906.20	2579992.00
# 194	518124.30	2738132.00
# 204	520764.80	2850668.00
# 207	524872.50	2907792.00
# 211	520763.80	2807577.00
# 216	540275.40	3875092.00
# 219	541728.90	4006716.00
# 232	515811.30	2405720.00
# 238	550890.10	5062894.00
# 248	525153.10	2911018.00
# 256	532218.00	3004937.00
# 257	535184.10	3239549.00
# 258	537387.10	3377690.00
# 259	537576.80	3471231.00
# 273	558763.90	6023649.00
# 274	554825.10	5473337.00
# 277	557315.10	5823571.00
# 285	557965.60	5988383.00
# 286	548285.40	4676986.00
# 289	540252.20	3774210.00
# 297	523705.40	2880091.00

# %%
print("\nPareto Optimal Solutions:\n")

for i, trial in enumerate(pareto_trials):
    print(f"Solution {i+1}")
    print("Trial number:", trial.number)
    print("FOPT (maximize):", trial.values[0])
    print("FWPT (minimize):", trial.values[1])
    print("Parameters:", trial.params)
    print("-" * 40)
# Out:
# Pareto Optimal Solutions:
#
# Solution 1
# Trial number: 99
# FOPT (maximize): 551243.7
# FWPT (minimize): 5318491.0
# Parameters: {'BHP1': 300, 'BHP2': 309, 'BHP3': 303, 'BHP4': 174, 'inj_rate1': 356, 'inj_rate2': 387, 'inj_rate3': 112, 'inj_rate4': 50, 'inj_rate5': 183, 'inj_rate6': 351, 'inj_rate7': 65, 'inj_rate8': 127}
# ----------------------------------------
# Solution 2
# Trial number: 108
# FOPT (maximize): 541661.8
# FWPT (minimize): 4006628.0
# Parameters: {'BHP1': 304, 'BHP2': 328, 'BHP3': 287, 'BHP4': 186, 'inj_rate1': 317, 'inj_rate2': 99, 'inj_rate3': 105, 'inj_rate4': 69, 'inj_rate5': 140, 'inj_rate6': 308, 'inj_rate7': 72, 'inj_rate8': 153}
# ----------------------------------------
# Solution 3
# Trial number: 119
# FOPT (maximize): 545717.1
# FWPT (minimize): 4589998.0
# Parameters: {'BHP1': 300, 'BHP2': 156, 'BHP3': 380, 'BHP4': 177, 'inj_rate1': 376, 'inj_rate2': 50, 'inj_rate3': 109, 'inj_rate4': 60, 'inj_rate5': 199, 'inj_rate6': 334, 'inj_rate7': 98, 'inj_rate8': 200}
# ----------------------------------------
# Solution 4
# Trial number: 121
# FOPT (maximize): 543399.8
# FWPT (minimize): 4105474.0
# Parameters: {'BHP1': 337, 'BHP2': 299, 'BHP3': 300, 'BHP4': 208, 'inj_rate1': 335, 'inj_rate2': 52, 'inj_rate3': 130, 'inj_rate4': 59, 'inj_rate5': 110, 'inj_rate6': 339, 'inj_rate7': 69, 'inj_rate8': 197}
# ----------------------------------------
# Solution 5
# Trial number: 125
# FOPT (maximize): 543941.1
# FWPT (minimize): 4317610.0
# Parameters: {'BHP1': 352, 'BHP2': 297, 'BHP3': 381, 'BHP4': 177, 'inj_rate1': 335, 'inj_rate2': 65, 'inj_rate3': 103, 'inj_rate4': 64, 'inj_rate5': 165, 'inj_rate6': 346, 'inj_rate7': 81, 'inj_rate8': 191}
# ----------------------------------------
# Solution 6
# Trial number: 128
# FOPT (maximize): 560304.8
# FWPT (minimize): 7145056.0
# Parameters: {'BHP1': 376, 'BHP2': 304, 'BHP3': 250, 'BHP4': 178, 'inj_rate1': 389, 'inj_rate2': 340, 'inj_rate3': 391, 'inj_rate4': 141, 'inj_rate5': 177, 'inj_rate6': 305, 'inj_rate7': 217, 'inj_rate8': 180}
# ----------------------------------------
# Solution 7
# Trial number: 131
# FOPT (maximize): 545695.8
# FWPT (minimize): 4406054.0
# Parameters: {'BHP1': 383, 'BHP2': 304, 'BHP3': 258, 'BHP4': 155, 'inj_rate1': 393, 'inj_rate2': 74, 'inj_rate3': 112, 'inj_rate4': 69, 'inj_rate5': 142, 'inj_rate6': 310, 'inj_rate7': 95, 'inj_rate8': 180}
# ----------------------------------------
# Solution 8
# Trial number: 134
# FOPT (maximize): 550974.3
# FWPT (minimize): 5292198.0
# Parameters: {'BHP1': 361, 'BHP2': 293, 'BHP3': 288, 'BHP4': 170, 'inj_rate1': 383, 'inj_rate2': 90, 'inj_rate3': 267, 'inj_rate4': 70, 'inj_rate5': 153, 'inj_rate6': 274, 'inj_rate7': 213, 'inj_rate8': 174}
# ----------------------------------------
# Solution 9
# Trial number: 140
# FOPT (maximize): 552284.1
# FWPT (minimize): 5432694.0
# Parameters: {'BHP1': 381, 'BHP2': 189, 'BHP3': 255, 'BHP4': 274, 'inj_rate1': 364, 'inj_rate2': 123, 'inj_rate3': 345, 'inj_rate4': 56, 'inj_rate5': 131, 'inj_rate6': 326, 'inj_rate7': 92, 'inj_rate8': 225}
# ----------------------------------------
# Solution 10
# Trial number: 143
# FOPT (maximize): 548916.2
# FWPT (minimize): 4896096.0
# Parameters: {'BHP1': 291, 'BHP2': 187, 'BHP3': 268, 'BHP4': 275, 'inj_rate1': 337, 'inj_rate2': 70, 'inj_rate3': 343, 'inj_rate4': 64, 'inj_rate5': 138, 'inj_rate6': 249, 'inj_rate7': 91, 'inj_rate8': 220}
# ----------------------------------------
# Solution 11
# Trial number: 167
# FOPT (maximize): 537733.5
# FWPT (minimize): 3701111.0
# Parameters: {'BHP1': 372, 'BHP2': 359, 'BHP3': 276, 'BHP4': 173, 'inj_rate1': 334, 'inj_rate2': 62, 'inj_rate3': 58, 'inj_rate4': 56, 'inj_rate5': 186, 'inj_rate6': 234, 'inj_rate7': 101, 'inj_rate8': 146}
# ----------------------------------------
# Solution 12
# Trial number: 171
# FOPT (maximize): 538788.4
# FWPT (minimize): 3743232.0
# Parameters: {'BHP1': 379, 'BHP2': 365, 'BHP3': 348, 'BHP4': 175, 'inj_rate1': 332, 'inj_rate2': 72, 'inj_rate3': 99, 'inj_rate4': 61, 'inj_rate5': 175, 'inj_rate6': 219, 'inj_rate7': 89, 'inj_rate8': 142}
# ----------------------------------------
# Solution 13
# Trial number: 178
# FOPT (maximize): 551276.9
# FWPT (minimize): 5322482.0
# Parameters: {'BHP1': 390, 'BHP2': 324, 'BHP3': 328, 'BHP4': 172, 'inj_rate1': 347, 'inj_rate2': 74, 'inj_rate3': 367, 'inj_rate4': 70, 'inj_rate5': 121, 'inj_rate6': 246, 'inj_rate7': 278, 'inj_rate8': 130}
# ----------------------------------------
# Solution 14
# Trial number: 190
# FOPT (maximize): 517906.2
# FWPT (minimize): 2579992.0
# Parameters: {'BHP1': 359, 'BHP2': 340, 'BHP3': 244, 'BHP4': 157, 'inj_rate1': 105, 'inj_rate2': 66, 'inj_rate3': 51, 'inj_rate4': 92, 'inj_rate5': 53, 'inj_rate6': 263, 'inj_rate7': 143, 'inj_rate8': 87}
# ----------------------------------------
# Solution 15
# Trial number: 194
# FOPT (maximize): 518124.3
# FWPT (minimize): 2738132.0
# Parameters: {'BHP1': 345, 'BHP2': 340, 'BHP3': 239, 'BHP4': 160, 'inj_rate1': 109, 'inj_rate2': 62, 'inj_rate3': 63, 'inj_rate4': 119, 'inj_rate5': 86, 'inj_rate6': 214, 'inj_rate7': 164, 'inj_rate8': 87}
# ----------------------------------------
# Solution 16
# Trial number: 204
# FOPT (maximize): 520764.8
# FWPT (minimize): 2850668.0
# Parameters: {'BHP1': 343, 'BHP2': 334, 'BHP3': 238, 'BHP4': 161, 'inj_rate1': 110, 'inj_rate2': 68, 'inj_rate3': 58, 'inj_rate4': 122, 'inj_rate5': 58, 'inj_rate6': 281, 'inj_rate7': 152, 'inj_rate8': 87}
# ----------------------------------------
# Solution 17
# Trial number: 207
# FOPT (maximize): 524872.5
# FWPT (minimize): 2907792.0
# Parameters: {'BHP1': 346, 'BHP2': 338, 'BHP3': 235, 'BHP4': 157, 'inj_rate1': 150, 'inj_rate2': 55, 'inj_rate3': 76, 'inj_rate4': 103, 'inj_rate5': 73, 'inj_rate6': 285, 'inj_rate7': 148, 'inj_rate8': 63}
# ----------------------------------------
# Solution 18
# Trial number: 211
# FOPT (maximize): 520763.8
# FWPT (minimize): 2807577.0
# Parameters: {'BHP1': 353, 'BHP2': 337, 'BHP3': 238, 'BHP4': 150, 'inj_rate1': 109, 'inj_rate2': 62, 'inj_rate3': 50, 'inj_rate4': 111, 'inj_rate5': 63, 'inj_rate6': 320, 'inj_rate7': 140, 'inj_rate8': 69}
# ----------------------------------------
# Solution 19
# Trial number: 216
# FOPT (maximize): 540275.4
# FWPT (minimize): 3875092.0
# Parameters: {'BHP1': 226, 'BHP2': 342, 'BHP3': 262, 'BHP4': 156, 'inj_rate1': 235, 'inj_rate2': 63, 'inj_rate3': 296, 'inj_rate4': 94, 'inj_rate5': 62, 'inj_rate6': 274, 'inj_rate7': 144, 'inj_rate8': 58}
# ----------------------------------------
# Solution 20
# Trial number: 219
# FOPT (maximize): 541728.9
# FWPT (minimize): 4006716.0
# Parameters: {'BHP1': 254, 'BHP2': 338, 'BHP3': 243, 'BHP4': 169, 'inj_rate1': 266, 'inj_rate2': 78, 'inj_rate3': 201, 'inj_rate4': 102, 'inj_rate5': 61, 'inj_rate6': 319, 'inj_rate7': 141, 'inj_rate8': 95}
# ----------------------------------------
# Solution 21
# Trial number: 232
# FOPT (maximize): 515811.3
# FWPT (minimize): 2405720.0
# Parameters: {'BHP1': 370, 'BHP2': 338, 'BHP3': 252, 'BHP4': 155, 'inj_rate1': 104, 'inj_rate2': 67, 'inj_rate3': 50, 'inj_rate4': 86, 'inj_rate5': 50, 'inj_rate6': 255, 'inj_rate7': 149, 'inj_rate8': 50}
# ----------------------------------------
# Solution 22
# Trial number: 238
# FOPT (maximize): 550890.1
# FWPT (minimize): 5062894.0
# Parameters: {'BHP1': 375, 'BHP2': 384, 'BHP3': 256, 'BHP4': 159, 'inj_rate1': 396, 'inj_rate2': 61, 'inj_rate3': 356, 'inj_rate4': 85, 'inj_rate5': 57, 'inj_rate6': 301, 'inj_rate7': 253, 'inj_rate8': 50}
# ----------------------------------------
# Solution 23
# Trial number: 248
# FOPT (maximize): 525153.1
# FWPT (minimize): 2911018.0
# Parameters: {'BHP1': 376, 'BHP2': 300, 'BHP3': 246, 'BHP4': 167, 'inj_rate1': 97, 'inj_rate2': 67, 'inj_rate3': 222, 'inj_rate4': 89, 'inj_rate5': 73, 'inj_rate6': 145, 'inj_rate7': 199, 'inj_rate8': 62}
# ----------------------------------------
# Solution 24
# Trial number: 256
# FOPT (maximize): 532218.0
# FWPT (minimize): 3004937.0
# Parameters: {'BHP1': 371, 'BHP2': 192, 'BHP3': 266, 'BHP4': 150, 'inj_rate1': 248, 'inj_rate2': 66, 'inj_rate3': 220, 'inj_rate4': 79, 'inj_rate5': 61, 'inj_rate6': 169, 'inj_rate7': 89, 'inj_rate8': 50}
# ----------------------------------------
# Solution 25
# Trial number: 257
# FOPT (maximize): 535184.1
# FWPT (minimize): 3239549.0
# Parameters: {'BHP1': 370, 'BHP2': 193, 'BHP3': 265, 'BHP4': 154, 'inj_rate1': 247, 'inj_rate2': 74, 'inj_rate3': 212, 'inj_rate4': 75, 'inj_rate5': 57, 'inj_rate6': 240, 'inj_rate7': 88, 'inj_rate8': 55}
# ----------------------------------------
# Solution 26
# Trial number: 258
# FOPT (maximize): 537387.1
# FWPT (minimize): 3377690.0
# Parameters: {'BHP1': 368, 'BHP2': 345, 'BHP3': 254, 'BHP4': 150, 'inj_rate1': 269, 'inj_rate2': 77, 'inj_rate3': 218, 'inj_rate4': 74, 'inj_rate5': 56, 'inj_rate6': 252, 'inj_rate7': 91, 'inj_rate8': 50}
# ----------------------------------------
# Solution 27
# Trial number: 259
# FOPT (maximize): 537576.8
# FWPT (minimize): 3471231.0
# Parameters: {'BHP1': 369, 'BHP2': 183, 'BHP3': 256, 'BHP4': 150, 'inj_rate1': 252, 'inj_rate2': 79, 'inj_rate3': 219, 'inj_rate4': 72, 'inj_rate5': 58, 'inj_rate6': 213, 'inj_rate7': 164, 'inj_rate8': 56}
# ----------------------------------------
# Solution 28
# Trial number: 273
# FOPT (maximize): 558763.9
# FWPT (minimize): 6023649.0
# Parameters: {'BHP1': 375, 'BHP2': 204, 'BHP3': 283, 'BHP4': 384, 'inj_rate1': 369, 'inj_rate2': 69, 'inj_rate3': 360, 'inj_rate4': 86, 'inj_rate5': 66, 'inj_rate6': 374, 'inj_rate7': 141, 'inj_rate8': 363}
# ----------------------------------------
# Solution 29
# Trial number: 274
# FOPT (maximize): 554825.1
# FWPT (minimize): 5473337.0
# Parameters: {'BHP1': 377, 'BHP2': 190, 'BHP3': 283, 'BHP4': 363, 'inj_rate1': 361, 'inj_rate2': 72, 'inj_rate3': 275, 'inj_rate4': 88, 'inj_rate5': 67, 'inj_rate6': 371, 'inj_rate7': 136, 'inj_rate8': 304}
# ----------------------------------------
# Solution 30
# Trial number: 277
# FOPT (maximize): 557315.1
# FWPT (minimize): 5823571.0
# Parameters: {'BHP1': 362, 'BHP2': 197, 'BHP3': 291, 'BHP4': 356, 'inj_rate1': 380, 'inj_rate2': 67, 'inj_rate3': 291, 'inj_rate4': 86, 'inj_rate5': 85, 'inj_rate6': 370, 'inj_rate7': 132, 'inj_rate8': 361}
# ----------------------------------------
# Solution 31
# Trial number: 285
# FOPT (maximize): 557965.6
# FWPT (minimize): 5988383.0
# Parameters: {'BHP1': 376, 'BHP2': 211, 'BHP3': 267, 'BHP4': 367, 'inj_rate1': 370, 'inj_rate2': 69, 'inj_rate3': 291, 'inj_rate4': 100, 'inj_rate5': 85, 'inj_rate6': 382, 'inj_rate7': 149, 'inj_rate8': 372}
# ----------------------------------------
# Solution 32
# Trial number: 286
# FOPT (maximize): 548285.4
# FWPT (minimize): 4676986.0
# Parameters: {'BHP1': 376, 'BHP2': 202, 'BHP3': 264, 'BHP4': 354, 'inj_rate1': 95, 'inj_rate2': 87, 'inj_rate3': 295, 'inj_rate4': 91, 'inj_rate5': 62, 'inj_rate6': 376, 'inj_rate7': 157, 'inj_rate8': 288}
# ----------------------------------------
# Solution 33
# Trial number: 289
# FOPT (maximize): 540252.2
# FWPT (minimize): 3774210.0
# Parameters: {'BHP1': 378, 'BHP2': 206, 'BHP3': 261, 'BHP4': 240, 'inj_rate1': 90, 'inj_rate2': 70, 'inj_rate3': 217, 'inj_rate4': 70, 'inj_rate5': 62, 'inj_rate6': 264, 'inj_rate7': 144, 'inj_rate8': 281}
# ----------------------------------------
# Solution 34
# Trial number: 297
# FOPT (maximize): 523705.4
# FWPT (minimize): 2880091.0
# Parameters: {'BHP1': 375, 'BHP2': 195, 'BHP3': 372, 'BHP4': 364, 'inj_rate1': 93, 'inj_rate2': 60, 'inj_rate3': 50, 'inj_rate4': 75, 'inj_rate5': 72, 'inj_rate6': 379, 'inj_rate7': 159, 'inj_rate8': 57}
# ----------------------------------------

# %% [markdown]
# # Knee point method best solution

# %%
import numpy as np

# Normalize
fopt_n = np.array([t.values[0] for t in pareto_trials])
fwpt_n = np.array([t.values[1] for t in pareto_trials])

# Line between extreme points
p1 = np.array([fwpt_n.min(), fopt_n.max()])
p2 = np.array([fwpt_n.max(), fopt_n.min()])

# Distance from each point to line
distances = []
for x, y in zip(fwpt_n, fopt_n):
    p = np.array([x, y])
    d = np.abs(np.cross(p2 - p1, p1 - p)) / np.linalg.norm(p2 - p1)
    distances.append(d)

# Knee point index
best_idx = np.argmax(distances)
best_trial_knee = pareto_trials[best_idx]

# --- Extract values ---
best_fopt = best_trial_knee.values[0]
best_fwpt = best_trial_knee.values[1]
params = best_trial_knee.params

# --- Separate BHP and Injection rates ---
bhp_params = {k: v for k, v in params.items() if "BHP" in k}
inj_params = {k: v for k, v in params.items() if "inj" in k.lower()}

# --- Print results ---
print("========== KNEE POINT SOLUTION ==========")
print(f"Trial Number : {best_trial_knee.number}")
print(f"FOPT         : {best_fopt}")
print(f"FWPT         : {best_fwpt}")

print("\n--- BHP Parameters ---")
for k, v in bhp_params.items():
    print(f"{k}: {v}")

print("\n--- Injection Rate Parameters ---")
for k, v in inj_params.items():
    print(f"{k}: {v}")
# Out:
# ========== KNEE POINT SOLUTION ==========
# Trial Number : 128
# FOPT         : 560304.8
# FWPT         : 7145056.0
#
# --- BHP Parameters ---
# BHP1: 376
# BHP2: 304
# BHP3: 250
# BHP4: 178
#
# --- Injection Rate Parameters ---
# inj_rate1: 389
# inj_rate2: 340
# inj_rate3: 391
# inj_rate4: 141
# inj_rate5: 177
# inj_rate6: 305
# inj_rate7: 217
# inj_rate8: 180
# C:\Users\hp\AppData\Local\Temp\ipykernel_13392\1421305971.py:15: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   d = np.abs(np.cross(p2 - p1, p1 - p)) / np.linalg.norm(p2 - p1)

# %% [markdown]
# # Best optimal with contraint

# %%
FWPT_max = 6900000  # constraint on water production

# Extract Pareto values
fopt = np.array([t.values[0] for t in pareto_trials])
fwpt = np.array([t.values[1] for t in pareto_trials])

# ===============================
# Apply constraint (FWPT <= limit)
# ===============================
valid_indices = [i for i, fw in enumerate(fwpt) if fw <= FWPT_max]

if valid_indices:

    # Select best FOPT among valid ones
    best_idx = max(valid_indices, key=lambda i: fopt[i])
    best_trial_constraint = pareto_trials[best_idx]

    # --- Extract values ---
    best_fopt = best_trial_constraint.values[0]
    best_fwpt = best_trial_constraint.values[1]
    params = best_trial_constraint.params

    # --- Separate BHP and Injection rates ---
    bhp_params = {k: v for k, v in params.items() if "BHP" in k}
    inj_params = {k: v for k, v in params.items() if "inj" in k.lower()}

    # --- Print results ---
    print("========== CONSTRAINED OPTIMAL SOLUTION ==========")
    print(f"Trial Number : {best_trial_constraint.number}")
    print(f"FOPT         : {best_fopt}")
    print(f"FWPT         : {best_fwpt}")

    print("\n--- BHP Parameters ---")
    for k, v in bhp_params.items():
        print(f"{k}: {v}")

    print("\n--- Injection Rate Parameters ---")
    for k, v in inj_params.items():
        print(f"{k}: {v}")

else:
    print("No Pareto solution satisfies the FWPT constraint.")
# Out:
# ========== CONSTRAINED OPTIMAL SOLUTION ==========
# Trial Number : 273
# FOPT         : 558763.9
# FWPT         : 6023649.0
#
# --- BHP Parameters ---
# BHP1: 375
# BHP2: 204
# BHP3: 283
# BHP4: 384
#
# --- Injection Rate Parameters ---
# inj_rate1: 369
# inj_rate2: 69
# inj_rate3: 360
# inj_rate4: 86
# inj_rate5: 66
# inj_rate6: 374
# inj_rate7: 141
# inj_rate8: 363

# %%
# ===============================
# Constraint definition
# ===============================
FWPT_max = 5700000  # constraint on water production

# Extract Pareto values
fopt = np.array([t.values[0] for t in pareto_trials])
fwpt = np.array([t.values[1] for t in pareto_trials])

# ===============================
# Apply constraint (FWPT <= limit)
# ===============================
valid_indices = [i for i, fw in enumerate(fwpt) if fw <= FWPT_max]

if valid_indices:

    # Select best FOPT among valid ones
    best_idx = max(valid_indices, key=lambda i: fopt[i])
    best_trial_constraint = pareto_trials[best_idx]

    # --- Extract values ---
    best_fopt = best_trial_constraint.values[0]
    best_fwpt = best_trial_constraint.values[1]
    params = best_trial_constraint.params

    # --- Separate BHP and Injection rates ---
    bhp_params = {k: v for k, v in params.items() if "BHP" in k}
    inj_params = {k: v for k, v in params.items() if "inj" in k.lower()}

    # --- Print results ---
    print("========== CONSTRAINED OPTIMAL SOLUTION ==========")
    print(f"Trial Number : {best_trial_constraint.number}")
    print(f"FOPT         : {best_fopt}")
    print(f"FWPT         : {best_fwpt}")

    print("\n--- BHP Parameters ---")
    for k, v in bhp_params.items():
        print(f"{k}: {v}")

    print("\n--- Injection Rate Parameters ---")
    for k, v in inj_params.items():
        print(f"{k}: {v}")

else:
    print("No Pareto solution satisfies the FWPT constraint.")
# Out:
# ========== CONSTRAINED OPTIMAL SOLUTION ==========
# Trial Number : 274
# FOPT         : 554825.1
# FWPT         : 5473337.0
#
# --- BHP Parameters ---
# BHP1: 377
# BHP2: 190
# BHP3: 283
# BHP4: 363
#
# --- Injection Rate Parameters ---
# inj_rate1: 361
# inj_rate2: 72
# inj_rate3: 275
# inj_rate4: 88
# inj_rate5: 67
# inj_rate6: 371
# inj_rate7: 136
# inj_rate8: 304
